# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# control display of seaborn data
pd. options.display.max_columns=50
sns.set(style="darkgrid", rc={"axes.facecolor":"CAF1DE"})

# %% [markdown]
# In[1] is all about importing the different libraries

# %%
#loading the dataset
print("question 1 reading the csv file")
df=pd.read_csv("AfricaCupofNationsMatches.csv")
print(df)
# Out:
# question 1 reading the csv file
#      Year                      Date   Time      HomeTeam       AwayTeam  \
# 0    1957                  10-Feb-57    NaN       Sudan           Egypt
# 1    1957                  10-Feb-57    NaN    Ethiopia    South Africa
# 2    1957                  16-Feb-57    NaN       Egypt        Ethiopia
# 3    1959                  22-May-59    NaN        Egypt       Ethiopia
# 4    1959                  25-May-59    NaN       Sudan        Ethiopia
# ..    ...                        ...    ...          ...            ...
# 617  2019  11 July 2019 (2019-07-11)  21:00  Madagascar         Tunisia
# 618  2019  14 July 2019 (2019-07-14)  18:00     Senegal         Tunisia
# 619  2019  14 July 2019 (2019-07-14)  21:00     Algeria         Nigeria
# 620  2019  17 July 2019 (2019-07-17)  21:00     Tunisia         Nigeria
# 621  2019  19 July 2019 (2019-07-19)  21:00     Senegal         Algeria
#
#      HomeTeamGoals  AwayTeamGoals                 Stage  \
# ...

# %% [markdown]
# In[37] is all about loading the dataset

# %%
#printing out the column names  i have
df.columns
# Out:
# Index(['Year', 'Date ', 'Time ', 'HomeTeam', 'AwayTeam', 'HomeTeamGoals',
#        'AwayTeamGoals', 'Stage', 'SpecialWinConditions', 'Stadium', 'City',
#        'Attendance'],
#       dtype='object')

# %%
# Remove spaces from column names
df.columns = df.columns.str.replace(' ', '')

# Print the modified column names
print(df.columns)
# Out:
# Index(['Year', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'HomeTeamGoals',
#        'AwayTeamGoals', 'Stage', 'SpecialWinConditions', 'Stadium', 'City',
#        'Attendance'],
#       dtype='object')

# %%
#checking information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 622 entries, 0 to 621
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Year                  622 non-null    int64
#  1   Date                  622 non-null    object
#  2   Time                  333 non-null    object
#  3   HomeTeam              622 non-null    object
#  4   AwayTeam              622 non-null    object
#  5   HomeTeamGoals         618 non-null    float64
#  6   AwayTeamGoals         618 non-null    float64
#  7   Stage                 622 non-null    object
#  8   SpecialWinConditions  56 non-null     object
#  9   Stadium               618 non-null    object
#  10  City                  618 non-null    object
#  11  Attendance            522 non-null    float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 58.4+ KB

# %%
#formating dates to  a uniform date format(datetime format and NaT for handling invalid dtaes)
df['Date'] = pd.to_datetime(df['Date'], errors='coerce')

# Print the modified 'date' column
print(df['Date'])
# Out:
# 0     2057-02-10
# 1     2057-02-10
# 2     2057-02-16
# 3     2059-05-22
# 4     2059-05-25
#          ...
# 617          NaT
# 618          NaT
# 619          NaT
# 620          NaT
# 621          NaT
# Name: Date, Length: 622, dtype: datetime64[ns]

# %%
print('first 7 rows it includes the column headers ')

print(df.head(7))
# Out:
# first 7 rows
#    Year       Date Time   HomeTeam       AwayTeam  HomeTeamGoals  \
# 0  1957 2057-02-10  NaN     Sudan           Egypt            1.0
# 1  1957 2057-02-10  NaN  Ethiopia    South Africa            NaN
# 2  1957 2057-02-16  NaN     Egypt        Ethiopia            4.0
# 3  1959 2059-05-22  NaN      Egypt       Ethiopia            4.0
# 4  1959 2059-05-25  NaN     Sudan        Ethiopia            1.0
# 5  1959 2059-05-29  NaN      Egypt          Sudan            2.0
# 6  1962 2062-01-14  NaN  Ethiopia         Tunisia            4.0
#
#    AwayTeamGoals             Stage  \
# 0            2.0        Semifinals
# 1            NaN        Semifinals
# 2            0.0             Final
# 3            0.0  Final Tournament
# 4            0.0  Final Tournament
# 5            1.0  Final Tournament
# 6            2.0        Semifinals
#
#                                 SpecialWinConditions                 Stadium  \
# ...

# %% [markdown]
# printing the first 7 rows of the dataframe

# %%
print('question 3 for selected columns')
selected_columns = df[['HomeTeam', 'AwayTeam', 'HomeTeamGoals','AwayTeamGoals']]
print(selected_columns)
# Out:
# question 3 for selected columns
#         HomeTeam       AwayTeam  HomeTeamGoals  AwayTeamGoals
# 0         Sudan           Egypt            1.0            2.0
# 1      Ethiopia    South Africa            NaN            NaN
# 2         Egypt        Ethiopia            4.0            0.0
# 3          Egypt       Ethiopia            4.0            0.0
# 4         Sudan        Ethiopia            1.0            0.0
# ..           ...            ...            ...            ...
# 617  Madagascar         Tunisia            0.0            3.0
# 618     Senegal         Tunisia            1.0            0.0
# 619     Algeria         Nigeria            2.0            1.0
# 620     Tunisia         Nigeria            0.0            1.0
# 621     Senegal         Algeria            0.0            1.0
#
# [622 rows x 4 columns]

# %% [markdown]
# question 3

# %%
print('question 4 for rows where egypt appears')
#this will output any row or column where Eqypt appears
selected_rows = df[df.eq('Egypt').any(axis=1)]

print(selected_rows)
# Out:
# question 4 for rows where egypt appears
#     Year       Date Time   HomeTeam   AwayTeam  HomeTeamGoals  AwayTeamGoals  \
# 3   1959 2059-05-22  NaN      Egypt   Ethiopia            4.0            0.0
# 5   1959 2059-05-29  NaN      Egypt      Sudan            2.0            1.0
# 7   1962 2062-01-18  NaN      Egypt     Uganda            2.0            1.0
# 9   1962 2062-01-21  NaN  Ethiopia       Egypt            4.0            2.0
# 13  1963 2063-11-24  NaN      Egypt    Nigeria            6.0            3.0
# 14  1963 2063-11-26  NaN      Egypt      Sudan            2.0            2.0
# 16  1963 2063-11-30  NaN      Egypt   Ethiopia            3.0            0.0
#
#                 Stage    SpecialWinConditions                 Stadium  \
# 3    Final Tournament                     NaN   Prince Farouk Stadium
# 5    Final Tournament                     NaN   Prince Farouk Stadium
# 7          Semifinals                     NaN  Hailé Sélassié Stadium
# ...

# %%
print('for counting number of rows and columns in my data frame')
num_rows = df.shape[0]
num_columns = df.shape[1]

print("Number of rows:", num_rows)
print("Number of columns:", num_columns)
# Out:
# for counting number of rows and columns in my data frame
# Number of rows: 622
# Number of columns: 12

# %%
print('6. selecting the rows where the ‘Attendance’ is missing.')
missing_attendance_rows = df[df['Attendance'].isna()]

print(missing_attendance_rows)
# Out:
# 6. selecting the rows where the ‘Attendance’ is missing.
#      Year       Date   Time       HomeTeam       AwayTeam  HomeTeamGoals  \
# 1    1957 2057-02-10    NaN      Ethiopia    South Africa            NaN
# 8    1962 2062-01-20    NaN       Tunisia          Uganda            3.0
# 9    1962 2062-01-21    NaN      Ethiopia           Egypt            4.0
# 10   1963 2063-11-24    NaN         Ghana         Tunisia            1.0
# 11   1963 2063-11-26    NaN         Ghana        Ethiopia            2.0
# ..    ...        ...    ...            ...            ...            ...
# 565  2017        NaT  20:00         Egypt         Morocco            1.0
# 566  2017        NaT  20:00  Burkina Faso           Egypt            1.0
# 567  2017        NaT  20:00      Cameroon           Ghana            2.0
# 568  2017        NaT  20:00  Burkina Faso           Ghana            1.0
# 569  2017        NaT  20:00         Egypt        Cameroon            1.0
#
# ...

# %%
print('7 selecting the rows where the ‘HomeTeamGoals’ are between 3 and 6 inclusive.')
# Assuming your dataframe is named 'df' and the column with HomeTeamGoals is named 'HomeTeamGoals'
selected_rows = df[(df['HomeTeamGoals'] >= 3) & (df['HomeTeamGoals'] <= 6)]

print(selected_rows)
# Out:
# 7 selecting the rows where the ‘HomeTeamGoals’ are between 3 and 6 inclusive.
#      Year       Date   Time   HomeTeam     AwayTeam  HomeTeamGoals  \
# 2    1957 2057-02-16    NaN     Egypt      Ethiopia            4.0
# 3    1959 2059-05-22    NaN      Egypt     Ethiopia            4.0
# 6    1962 2062-01-14    NaN  Ethiopia       Tunisia            4.0
# 8    1962 2062-01-20    NaN   Tunisia        Uganda            3.0
# 9    1962 2062-01-21    NaN  Ethiopia         Egypt            4.0
# ..    ...        ...    ...        ...          ...            ...
# 553  2017        NaT  20:00   Morocco          Togo            3.0
# 585  2019        NaT  22:00     Kenya      Tanzania            3.0
# 595  2019        NaT  22:00      Mali    Mauritania            4.0
# 608  2019        NaT  18:00   Nigeria      Cameroon            3.0
# 611  2019        NaT  21:00   Algeria        Guinea            3.0
#
#      AwayTeamGoals              Stage    SpecialWinConditions  \
# ...

# %%
print('8.changing the “AwayTeamGoals” in the 3rd row to 10')

df.at[2, 'AwayTeamGoals'] = 10

print(df)
# Out:
# 8.changing the “AwayTeamGoals” in the 3rd row to 10
#      Year       Date   Time     HomeTeam       AwayTeam  HomeTeamGoals  \
# 0    1957 2057-02-10    NaN       Sudan           Egypt            1.0
# 1    1957 2057-02-10    NaN    Ethiopia    South Africa            NaN
# 2    1957 2057-02-16    NaN       Egypt        Ethiopia            4.0
# 3    1959 2059-05-22    NaN        Egypt       Ethiopia            4.0
# 4    1959 2059-05-25    NaN       Sudan        Ethiopia            1.0
# ..    ...        ...    ...          ...            ...            ...
# 617  2019        NaT  21:00  Madagascar         Tunisia            0.0
# 618  2019        NaT  18:00     Senegal         Tunisia            1.0
# 619  2019        NaT  21:00     Algeria         Nigeria            2.0
# 620  2019        NaT  21:00     Tunisia         Nigeria            0.0
# 621  2019        NaT  21:00     Senegal         Algeria            0.0
#
#      AwayTeamGoals                 Stage  \
# ...

# %%
print('sorting')

sorted_df = df.sort_values(by=['HomeTeam', 'HomeTeamGoals'], ascending=[True, False])

print(sorted_df)
# Out:
# sorting
#      Year       Date           Time   HomeTeam      AwayTeam  HomeTeamGoals  \
# 205  1990 1990-03-02            NaN   Algeria        Nigeria            5.0
# 29   1968 2068-01-14            NaN   Algeria         Uganda            4.0
# 135  1980 1980-03-16            NaN   Algeria         Guinea            3.0
# 164  1984 1984-03-05            NaN   Algeria         Malawi            3.0
# 171  1984 1984-03-17            NaN   Algeria          Egypt            3.0
# ..    ...        ...            ...        ...           ...            ...
# 521  2012 2012-02-12  20:30[note 1]    Zambia    Ivory Coast            0.0
# 549  2017        NaT          20:00  Zimbabwe        Tunisia            2.0
# 398  2004 2004-01-25          16:30  Zimbabwe          Egypt            1.0
# 437  2006 2006-01-23          20:00  Zimbabwe        Senegal            0.0
# 575  2019        NaT          21:00  Zimbabwe       DR Congo            0.0
#
# ...

# %%
print('lists')
column_headers = df.columns.tolist()

print(column_headers)
# Out:
# lists
# ['Year', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'HomeTeamGoals', 'AwayTeamGoals', 'Stage', 'SpecialWinConditions', 'Stadium', 'City', 'Attendance']

# %%
#appending a column of my choice
countries = ['Uganda', 'Rwanda', 'Kenya', 'Nigeria', 'Tanzania']

df['African'] = countries * (len(df) // len(countries)) + countries[:len(df) % len(countries)]

print(df)
# Out:
#      Year       Date   Time     HomeTeam       AwayTeam  HomeTeamGoals  \
# 0    1957 2057-02-10    NaN       Sudan           Egypt            1.0
# 1    1957 2057-02-10    NaN    Ethiopia    South Africa            NaN
# 2    1957 2057-02-16    NaN       Egypt        Ethiopia            4.0
# 3    1959 2059-05-22    NaN        Egypt       Ethiopia            4.0
# 4    1959 2059-05-25    NaN       Sudan        Ethiopia            1.0
# ..    ...        ...    ...          ...            ...            ...
# 617  2019        NaT  21:00  Madagascar         Tunisia            0.0
# 618  2019        NaT  18:00     Senegal         Tunisia            1.0
# 619  2019        NaT  21:00     Algeria         Nigeria            2.0
# 620  2019        NaT  21:00     Tunisia         Nigeria            0.0
# 621  2019        NaT  21:00     Senegal         Algeria            0.0
#
#      AwayTeamGoals                 Stage  \
# 0              2.0            Semifinals
# ...

# %%
print('add two rows')
new_rows = [{'Cathy': 11, 'Carol': 22, 'Cythia': 23},
            {'Toff': 24, 'Kelly': 25, 'Kenny': 26}]

df = pd.concat([df, pd.DataFrame(new_rows)], ignore_index=True)

print(df)
# Out:
# add two rows
#        Year       Date   Time   HomeTeam       AwayTeam  HomeTeamGoals  \
# 0    1957.0 2057-02-10    NaN     Sudan           Egypt            1.0
# 1    1957.0 2057-02-10    NaN  Ethiopia    South Africa            NaN
# 2    1957.0 2057-02-16    NaN     Egypt        Ethiopia            4.0
# 3    1959.0 2059-05-22    NaN      Egypt       Ethiopia            4.0
# 4    1959.0 2059-05-25    NaN     Sudan        Ethiopia            1.0
# ..      ...        ...    ...        ...            ...            ...
# 621  2019.0        NaT  21:00   Senegal         Algeria            0.0
# 622     NaN        NaT    NaN        NaN            NaN            NaN
# 623     NaN        NaT    NaN        NaN            NaN            NaN
# 624     NaN        NaT    NaN        NaN            NaN            NaN
# 625     NaN        NaT    NaN        NaN            NaN            NaN
#
#      AwayTeamGoals             Stage  \
# 0              2.0        Semifinals
# ...

# %%
df['AwayTeam'] = df['AwayTeam'].str.strip().replace('Uganda', 'China')

print(df.head(10))
# Out:
#    Year      Date  Time    HomeTeam      AwayTeam HomeTeamGoals  \
# 0  1957  10-Feb-57   NaN     Sudan          Egypt           1.0
# 1  1957  10-Feb-57   NaN  Ethiopia   South Africa         Other
# 2  1957  16-Feb-57   NaN     Egypt       Ethiopia         Other
# 3  1959  22-May-59   NaN      Egypt      Ethiopia         Other
# 4  1959  25-May-59   NaN     Sudan       Ethiopia           1.0
# 5  1959  29-May-59   NaN      Egypt         Sudan         Other
# 6  1962  14-Jan-62   NaN  Ethiopia        Tunisia         Other
# 7  1962  18-Jan-62   NaN      Egypt         China         Other
# 8  1962  20-Jan-62   NaN   Tunisia          China         Other
# 9  1962  21-Jan-62   NaN  Ethiopia          Egypt         Other
#
#    AwayTeamGoals              Stage  \
# 0            2.0         Semifinals
# 1            NaN         Semifinals
# 2            0.0              Final
# 3            0.0   Final Tournament
# 4            0.0   Final Tournament
# 5            1.0   Final Tournament
# ...

# %% [markdown]
# In[45] i used  the head function to able to diplay the changes easily,str.strip() to remove any leading or trailing whitespaces from the values in 'AwayTeam'

# %%
df.reset_index(drop=True, inplace=True)

print(df)
# Out:
#        Year       Date   Time   HomeTeam       AwayTeam  HomeTeamGoals  \
# 0    1957.0 2057-02-10    NaN     Sudan           Egypt            1.0
# 1    1957.0 2057-02-10    NaN  Ethiopia    South Africa            NaN
# 2    1957.0 2057-02-16    NaN     Egypt        Ethiopia            4.0
# 3    1959.0 2059-05-22    NaN      Egypt       Ethiopia            4.0
# 4    1959.0 2059-05-25    NaN     Sudan        Ethiopia            1.0
# ..      ...        ...    ...        ...            ...            ...
# 621  2019.0        NaT  21:00   Senegal         Algeria            0.0
# 622     NaN        NaT    NaN        NaN            NaN            NaN
# 623     NaN        NaT    NaN        NaN            NaN            NaN
# 624     NaN        NaT    NaN        NaN            NaN            NaN
# 625     NaN        NaT    NaN        NaN            NaN            NaN
#
#      AwayTeamGoals             Stage  \
# 0              2.0        Semifinals
# ...

# %%
print('checking for presence of Stadium')
if 'Stadium' in df.columns:
    print("The 'Stadium' column is present.")
else:
    print("The 'Stadium' column is not present.")
# Out:
# checking for presence of Stadium
# The 'Stadium' column is present.

# %%
print('converting datatype')
df['AwayTeamGoals'] = df['AwayTeamGoals'].astype(float)

print(df.dtypes)
# Out:
# converting datatype
# Year                           float64
# Date                    datetime64[ns]
# Time                            object
# HomeTeam                        object
# AwayTeam                        object
# HomeTeamGoals                  float64
# AwayTeamGoals                  float64
# Stage                           object
# SpecialWinConditions            object
# Stadium                         object
# City                            object
# Attendance                     float64
# African                         object
# Cathy                          float64
# Toff                           float64
# Gog                            float64
# kenny                          float64
# sheila                         float64
# Kelly                          float64
# Carol                          float64
# Cythia                         float64
# Kenny                          float64
# dtype: object

# %%
print('removing the last 10 rows')
df = df[:-10]

print(df)
# Out:
# removing the last 10 rows
#        Year       Date   Time   HomeTeam       AwayTeam  HomeTeamGoals  \
# 0    1957.0 2057-02-10    NaN     Sudan           Egypt            1.0
# 1    1957.0 2057-02-10    NaN  Ethiopia    South Africa            NaN
# 2    1957.0 2057-02-16    NaN     Egypt        Ethiopia            4.0
# 3    1959.0 2059-05-22    NaN      Egypt       Ethiopia            4.0
# 4    1959.0 2059-05-25    NaN     Sudan        Ethiopia            1.0
# ..      ...        ...    ...        ...            ...            ...
# 611  2019.0        NaT  21:00   Algeria          Guinea            3.0
# 612  2019.0        NaT  18:00      Mali     Ivory Coast            0.0
# 613  2019.0        NaT  21:00     Ghana         Tunisia            1.0
# 614  2019.0        NaT  18:00   Senegal           Benin            1.0
# 615  2019.0        NaT  21:00   Nigeria    South Africa            2.0
#
#      AwayTeamGoals             Stage  \
# 0              2.0        Semifinals
# ...

# %% [markdown]
# In[29] i used slicing to select all rows except the last 10 rows

# %%
print('iterate over rows')
for index, row in df.iterrows():
    year = row['Year']
    date = row['Date']
    time = row['Time']
    home_team = row['HomeTeam']
    away_team = row['AwayTeam']
    home_goals = row['HomeTeamGoals']
    away_goals = row['AwayTeamGoals']
    stage = row['Stage']
    special_win_conditions = row['SpecialWinConditions']
    stadium = row['Stadium']
    city = row['City']
    attendance = row['Attendance']
    
    # Print or process row data
    print(f"Row {index}: Year={year}, Date={date}, Time={time}, HomeTeam={home_team}, AwayTeam={away_team}, "
          f"HomeTeamGoals={home_goals}, AwayTeamGoals={away_goals}, Stage={stage}, "
          f"SpecialWinConditions={special_win_conditions}, Stadium={stadium}, City={city}, Attendance={attendance}")
# Out:
# iterate over rows
# Row 0: Year=1957.0, Date=2057-02-10 00:00:00, Time=nan, HomeTeam=Sudan , AwayTeam= Egypt, HomeTeamGoals=1.0, AwayTeamGoals=2.0, Stage=Semifinals, SpecialWinConditions=nan, Stadium=Municipal Stadium, City= Khartoum, Attendance=30000.0
# Row 1: Year=1957.0, Date=2057-02-10 00:00:00, Time=nan, HomeTeam=Ethiopia , AwayTeam= South Africa, HomeTeamGoals=nan, AwayTeamGoals=nan, Stage=Semifinals, SpecialWinConditions=Ethiopia  wins due to disqualification of other team, Stadium=nan, City=nan, Attendance=nan
# Row 2: Year=1957.0, Date=2057-02-16 00:00:00, Time=nan, HomeTeam=Egypt , AwayTeam= Ethiopia, HomeTeamGoals=4.0, AwayTeamGoals=10.0, Stage=Final, SpecialWinConditions=nan, Stadium=Municipal Stadium, City= Khartoum, Attendance=30000.0
# ...

# %%
print('for changing')
new_column_order = ['Year', 'Date', 'Time', 'HomeTeam', 'AwayTeam', 'HomeTeamGoals',
                    'AwayTeamGoals', 'Stage', 'SpecialWinConditions', 'Stadium',
                    'City', 'Attendance']

df = df.reindex(columns=new_column_order)

print(df)
# Out:
# for changing
#        Year       Date   Time   HomeTeam       AwayTeam  HomeTeamGoals  \
# 0    1957.0 2057-02-10    NaN     Sudan           Egypt            1.0
# 1    1957.0 2057-02-10    NaN  Ethiopia    South Africa            NaN
# 2    1957.0 2057-02-16    NaN     Egypt        Ethiopia            4.0
# 3    1959.0 2059-05-22    NaN      Egypt       Ethiopia            4.0
# 4    1959.0 2059-05-25    NaN     Sudan        Ethiopia            1.0
# ..      ...        ...    ...        ...            ...            ...
# 611  2019.0        NaT  21:00   Algeria          Guinea            3.0
# 612  2019.0        NaT  18:00      Mali     Ivory Coast            0.0
# 613  2019.0        NaT  21:00     Ghana         Tunisia            1.0
# 614  2019.0        NaT  18:00   Senegal           Benin            1.0
# 615  2019.0        NaT  21:00   Nigeria    South Africa            2.0
#
#      AwayTeamGoals             Stage  \
# 0              2.0        Semifinals
# ...

# %% [markdown]
# print('deleting DataFrame row(s) whose value is 0 in the ‘HomeTeamGoals’ columns.')
# df = df[df['HomeTeamGoals'] != 0]
# print(df)

# %%
df = df[df['HomeTeamGoals'] != 0]

print(df)
# Out:
#        Year       Date   Time     HomeTeam       AwayTeam  HomeTeamGoals  \
# 0    1957.0 2057-02-10    NaN       Sudan           Egypt            1.0
# 1    1957.0 2057-02-10    NaN    Ethiopia    South Africa            NaN
# 2    1957.0 2057-02-16    NaN       Egypt        Ethiopia            4.0
# 3    1959.0 2059-05-22    NaN        Egypt       Ethiopia            4.0
# 4    1959.0 2059-05-25    NaN       Sudan        Ethiopia            1.0
# ..      ...        ...    ...          ...            ...            ...
# 610  2019.0        NaT  18:00  Madagascar        DR Congo            2.0
# 611  2019.0        NaT  21:00     Algeria          Guinea            3.0
# 613  2019.0        NaT  21:00       Ghana         Tunisia            1.0
# 614  2019.0        NaT  18:00     Senegal           Benin            1.0
# 615  2019.0        NaT  21:00     Nigeria    South Africa            2.0
#
#      AwayTeamGoals             Stage  \
# 0              2.0        Semifinals
# ...

# %% [markdown]
# attempting question 1 of series

# %%
# Define the sample series
series1 = pd.Series([4, 65, 436, 3, 9])
series2 = pd.Series([7, 0, 3, 897, 9])

# Compare the series using the equals() method
comparison_result = series1.equals(series2)

print(comparison_result)
# Out:
# False

# %% [markdown]
# pandas program dealing with series to add,multiply,divide,subtract

# %%
# Define the sample series
series1 = pd.Series([2, 4, 6, 8, 14])
series2 = pd.Series([1, 3, 5, 7, 9])

# Perform arithmetic operations
addition_result = series1 + series2
subtraction_result = series1 - series2
multiplication_result = series1 * series2
division_result = series1 / series2

print("Addition Result:")
print(addition_result)

print("Subtraction Result:")
print(subtraction_result)

print("Multiplication Result:")
print(multiplication_result)

print("Division Result:")
print(division_result)
# Out:
# Addition Result:
# 0     3
# 1     7
# 2    11
# 3    15
# 4    23
# dtype: int64
# Subtraction Result:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    5
# dtype: int64
# Multiplication Result:
# 0      2
# 1     12
# 2     30
# 3     56
# 4    126
# dtype: int64
# Division Result:
# 0    2.000000
# 1    1.333333
# 2    1.200000
# 3    1.142857
# 4    1.555556
# dtype: float64

# %% [markdown]
# converting dictionary to series

# %%
# Define the sample dictionary
dictionary1 = {'Josh': 24, 'Sam': 36, 'Peace': 19, 'Charles': 65, 'Tom': 44}

# Convert the dictionary to a Pandas Series
series1 = pd.Series(dictionary1)

print(series1)
# Out:
# Josh       24
# Sam        36
# Peace      19
# Charles    65
# Tom        44
# dtype: int64

# %% [markdown]
# converting series to array

# %%
# Define the sample series
series1 = pd.Series(['Love', 800, 'Joy', 789.9, 'Peace', True])

# Convert the series to an array
array1 = series1.to_numpy()

print(array1)
# Out:
# ['Love' 800 'Joy' 789.9 'Peace' True]

# %%
# Assuming your dataframe is named 'df'
series = df['HomeTeamGoals']

# Find the most frequent value
most_frequent = series.value_counts().idxmax()

# Replace everything else as 'Other'
series[~(series == most_frequent)] = 'Other'

print(series)
# Out:
# 0        1.0
# 1      Other
# 2      Other
# 3      Other
# 4        1.0
#        ...
# 617    Other
# 618      1.0
# 619    Other
# 620    Other
# 621    Other
# Name: HomeTeamGoals, Length: 622, dtype: object
# C:\Users\laptop\AppData\Local\Temp\ipykernel_1976\1822230838.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   series[~(series == most_frequent)] = 'Other'
