# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# control display of seaborn data
pd. options.display.max_columns=50
sns.set(style="darkgrid", rc={"axes.facecolor":"CAF1DE"})

# %%
data1=pd.read_csv('2018CrimeStatisticsByCategoryOfCrime.csv')
data1
# Out:
#     Unnamed: 0             Unnamed: 1 REPORTED CASES           Unnamed: 3  \
# 0          NaN                    NaN            NaN                  NaN
# 1          NaN                    NaN   Totals Cases  Cases under Inquiry
# 2        S/No.  CASE/CRIME INCIDENCES              1                    2
# 3          NaN              HOMICIDES            NaN                  NaN
# 4            1   Death  (by shooting)            190                  117
# ..         ...                    ...            ...                  ...
# 122         98            UWA Statute            648                  112
# 123         99   Local Government Act              4                    2
# 124        100         All other Acts            821                  345
# 125        NaN  Sub Total(Other Laws)          3,006                  749
# 126        NaN            GRAND TOTAL        238,746               90,763
#
#            Unnamed: 4            Unnamed: 5                 PERFOMANCE  \
# ...

# %%
#import pandas as pd

df5 = pd.read_csv('UceResultsBySchool2011-2016.csv')

df5
# Out:
#        YEAR      DISTRICT                                              SCHOOL  \
# 0      2011         WAKISO                                 GAYAZA HIGH SCHOOL
# 1      2011         MUKONO                                 NAMILYANGO COLLEGE
# 2      2011         MUKONO                             MT.ST.MARY'S,NAMAGUNGA
# 3      2011         WAKISO                        UGANDA MARTYRS SS,NAMUGONGO
# 4      2011  BUSHENYI MAIN                                    KITABI SEMINARY
# ...     ...            ...                                                ...
# 17634  2016          ZOMBO      PAIDHA SECONDARY SCHOOL    P.O.BOX 117 PAIDHA
# 17635  2016          ZOMBO  PAKADHA SEED SECONDARY SCHOOL    P.O.BOX 143 P...
# 17636  2016          ZOMBO        CHARITY COLLEGE,PAIDHA    P.O.BOX 47 PAIDHA
# 17637  2016          ZOMBO  NEGRINI MEM. SECONDARY SCHOOL    P.O.BOX 156 P...
# 17638  2016          ZOMBO   JANGOKORO SEED SEC. SCHOOL    P.O.BOX 139 PAIDHA
#
# ...

# %%
import pandas as pd

df6 = pd.read_csv('MPsProfileInformation10thParliament.csv', encoding='latin-1')

df6
# Out:
#      No.                      Name of M.P   District  \
# 0      1               Aadroa Alex Onzima       None
# 1      2                    Ababiku Jesca   Adjumani
# 2      3  ABACANON CHARLES ANGIRO GUTOMOI       Lira
# 3      4                      ABALA DAVID      Ngora
# 4      5             ABBAS AGABA MUGISHA    Kamwenge
# ..   ...                              ...        ...
# 434  435            Wekomba Nambozo Sarah  Bulambuli
# 435  436         Werikhe Kafabusa Michael      Mbale
# 436  437                    Woboya Vicent    Sironko
# 437  438               Yaguma Wilberforce    Mbarara
# 438  439                    Zaake Francis    Mityana
#
#                       Constituency Political Party       Profession  \
# 0                       Ex-Officio            None    Administrator
# 1    District Woman Representative             NRM          Teacher
# 2               ERUTE COUNTY NORTH             FDC           Farmer
# ...

# %%
df6.columns
# Out:
# Index(['No.', 'Name of M.P', 'District', 'Constituency', 'Political Party',
#        'Profession', 'Marital status', 'Phone number', 'Date of Birth',
#        'P.L.E School', 'P.L.E Year', 'U.C.E School', 'U.C.E Year',
#        'U.A.C.E School', 'U.A.C.E Year', 'First Degree',
#        'University of First Degree', 'Year of first Degree', 'Second Degree',
#        'University of Second Degree', 'Year of second degree', 'Third Degree',
#        'University of Third Degree', 'Year of Third Degree',
#        'Other Qualifications', 'Past Job_1', 'Past Job_2', 'Past Job_3',
#        'Past Job_4', 'Past Job_5', 'Past Job_6', 'Past Job_7', 'Past Job_8',
#        'Past Job_9', 'Past Job_10', 'Hobbies', 'Special Interests',
#        'Other Information', 'Professional Body Membership', 'Committee_1',
#        'Role on Committee 1', 'Committee_2', 'Role on Committee 2',
#        'Committee_3', 'Role on Committee 3', 'Committee_4',
# ...

# %%
df5.columns
# Out:
# Index(['YEAR', 'DISTRICT ', 'SCHOOL', 'TOTAL CANDIDATES', 'TOTAL DIV 1',
#        '% DIV 1', 'TOTAL DIV 2', '% DIV 2', 'TOTAL DIV 3', '% DIV 3',
#        'TOTAL DIV 4', '% DIV 4', 'TOTAL DIV 7', '% DIV 7', 'TOTAL DIV 9',
#        '% DIV 9', 'TOTAL X', '% X', 'FEMALE CANDIDATES', 'FEMALE TOTAL DIV1 ',
#        'FEMALE % DIV1 ', 'FEMALE TOTAL DIV2 ', 'FEMALE % DIV2',
#        'FEMALE TOTAL DIV3', 'FEMALE % DIV3', 'FEMALE TOTAL DIV4',
#        'FEMALE % DIV4', 'FEMALE TOTAL DIV7', 'FEMALE % DIV7',
#        'FEMALE TOTAL DIV9', 'FEMALE % DIV9', 'FEMALE TOTAL X', 'FEMALE % X ',
#        'MALE CANDIDATES', 'MALE TOTAL DIV1 ', 'MALE % DIV1 ',
#        'MALE TOTAL DIV2 ', 'MALE % DIV2', 'MALE TOTAL DIV3', 'MALE % DIV3',
#        'MALE TOTAL DIV4', 'MALE % DIV4 ', 'MALE TOTAL DIV7 ', 'MALE % DIV7',
#        'MALE TOTAL DIV9 ', 'MALE % DIV9', 'MALE TOTAL X ', 'MALE % X'],
#       dtype='object')

# %%
data1.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'REPORTED CASES', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5', 'PERFOMANCE', 'Unnamed: 7', 'Unnamed: 8',
#        'Unnamed: 9', 'Unnamed: 10', 'PERSONS TAKEN TO COURT', 'Unnamed: 12',
#        'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16',
#        'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20',
#        'Unnamed: 21', 'SENTENCES IMPOSED BY COURTS', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Unnamed: 29', 'Unnamed: 30', 'Unnamed: 31',
#        'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35',
#        'Unnamed: 36', 'Unnamed: 37'],
#       dtype='object')

# %%
print(data1.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 122    False
# 123    False
# 124    False
# 125    False
# 126    False
# Length: 127, dtype: bool

# %%
print(df5.duplicated())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 17634    False
# 17635    False
# 17636    False
# 17637    False
# 17638    False
# Length: 17639, dtype: bool

# %%
print(df6.duplicated())
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 434    False
# 435    False
# 436    False
# 437    False
# 438    False
# Length: 439, dtype: bool

# %%
# Check for missing values
missing_values = data1.isnull().sum()
print(missing_values)
# Out:
# Unnamed: 0                     32
# Unnamed: 1                      2
# REPORTED CASES                  2
# Unnamed: 3                      2
# Unnamed: 4                      2
# Unnamed: 5                      2
# PERFOMANCE                      2
# Unnamed: 7                      2
# Unnamed: 8                      2
# Unnamed: 9                      2
# Unnamed: 10                     2
# PERSONS TAKEN TO COURT          1
# Unnamed: 12                     3
# Unnamed: 13                     3
# Unnamed: 14                     3
# Unnamed: 15                     1
# Unnamed: 16                     3
# Unnamed: 17                     3
# Unnamed: 18                     3
# Unnamed: 19                    18
# Unnamed: 20                    18
# Unnamed: 21                    18
# SENTENCES IMPOSED BY COURTS    18
# Unnamed: 23                    19
# Unnamed: 24                    19
# Unnamed: 25                    18
# Unnamed: 26                    18
# ...

# %%
# Check for missing values
missing_values = df5.isnull().sum()
print(missing_values)
# Out:
# YEAR                      0
# DISTRICT                  0
# SCHOOL                    1
# TOTAL CANDIDATES        271
# TOTAL DIV 1            4781
# % DIV 1                   0
# TOTAL DIV 2             759
# % DIV 2                   0
# TOTAL DIV 3             471
# % DIV 3                   0
# TOTAL DIV 4             751
# % DIV 4                   0
# TOTAL DIV 7           11150
# % DIV 7                   0
# TOTAL DIV 9            4185
# % DIV 9                   0
# TOTAL X                4235
# % X                       0
# FEMALE CANDIDATES         0
# FEMALE TOTAL DIV1      9114
# FEMALE % DIV1            58
# FEMALE TOTAL DIV2      3307
# FEMALE % DIV2            58
# FEMALE TOTAL DIV3      1165
# FEMALE % DIV3            58
# FEMALE TOTAL DIV4       958
# FEMALE % DIV4            58
# FEMALE TOTAL DIV7     12875
# FEMALE % DIV7            58
# FEMALE TOTAL DIV9      5290
# FEMALE % DIV9            58
# FEMALE TOTAL X         7043
# FEMALE % X               58
# ...

# %%
# Check for missing values
missing_values = df6.isnull().sum()
print(missing_values)
# Out:
# No.                  0
# Name of M.P          0
# District             0
# Constituency         0
# Political Party      0
#                   ...
# Unnamed: 82        438
# Unnamed: 83        439
# Unnamed: 84        438
# Unnamed: 85        438
# Unnamed: 86        438
# Length: 87, dtype: int64

# %%
# Check for null values in a specific column

null_values = df5['TOTAL DIV 4'].isnull().sum()
print(null_values)
# Out:
# 751

# %%
md=df5['TOTAL DIV 4'].median()
df5['TOTAL DIV 4'].fillna(md,inplace=True)
print(df5)
# Out:
#        YEAR      DISTRICT                                              SCHOOL  \
# 0      2011         WAKISO                                 GAYAZA HIGH SCHOOL
# 1      2011         MUKONO                                 NAMILYANGO COLLEGE
# 2      2011         MUKONO                             MT.ST.MARY'S,NAMAGUNGA
# 3      2011         WAKISO                        UGANDA MARTYRS SS,NAMUGONGO
# 4      2011  BUSHENYI MAIN                                    KITABI SEMINARY
# ...     ...            ...                                                ...
# 17634  2016          ZOMBO      PAIDHA SECONDARY SCHOOL    P.O.BOX 117 PAIDHA
# 17635  2016          ZOMBO  PAKADHA SEED SECONDARY SCHOOL    P.O.BOX 143 P...
# 17636  2016          ZOMBO        CHARITY COLLEGE,PAIDHA    P.O.BOX 47 PAIDHA
# 17637  2016          ZOMBO  NEGRINI MEM. SECONDARY SCHOOL    P.O.BOX 156 P...
# 17638  2016          ZOMBO   JANGOKORO SEED SEC. SCHOOL    P.O.BOX 139 PAIDHA
#
# ...

# %%
dups=df5['TOTAL DIV 4'].duplicated
print(dups)
# Out:
# <bound method Series.duplicated of 0        38.0
# 1        38.0
# 2        38.0
# 3        38.0
# 4        38.0
#          ...
# 17634    85.0
# 17635    50.0
# 17636    71.0
# 17637    26.0
# 17638    25.0
# Name: TOTAL DIV 4, Length: 17639, dtype: float64>

# %%
# Check for null values in a specific column

null_values = data1['REPORTED CASES'].isnull().sum()
print(null_values)
# Out:
# 2

# %%
data1['REPORTED CASES'].fillna("theft",inplace=True)
print(data1)
# Out:
#     Unnamed: 0             Unnamed: 1 REPORTED CASES           Unnamed: 3  \
# 0          NaN                    NaN          theft                  NaN
# 1          NaN                    NaN   Totals Cases  Cases under Inquiry
# 2        S/No.  CASE/CRIME INCIDENCES              1                    2
# 3          NaN              HOMICIDES          theft                  NaN
# 4            1   Death  (by shooting)            190                  117
# ..         ...                    ...            ...                  ...
# 122         98            UWA Statute            648                  112
# 123         99   Local Government Act              4                    2
# 124        100         All other Acts            821                  345
# 125        NaN  Sub Total(Other Laws)          3,006                  749
# 126        NaN            GRAND TOTAL        238,746               90,763
#
#            Unnamed: 4            Unnamed: 5                 PERFOMANCE  \
# ...

# %%
null_values = data1['PERSONS TAKEN TO COURT'].isnull().sum()
print(null_values)
# Out:
# 1

# %%
null_values = data1['PERFOMANCE'].isnull().sum()
print(null_values)
# Out:
# 2

# %%
null_values = data1.isnull().sum()
print(null_values)
# Out:
# Unnamed: 0                     32
# Unnamed: 1                      2
# REPORTED CASES                  0
# Unnamed: 3                      2
# Unnamed: 4                      2
# Unnamed: 5                      2
# PERFOMANCE                      2
# Unnamed: 7                      2
# Unnamed: 8                      2
# Unnamed: 9                      2
# Unnamed: 10                     2
# PERSONS TAKEN TO COURT          1
# Unnamed: 12                     3
# Unnamed: 13                     3
# Unnamed: 14                     3
# Unnamed: 15                     1
# Unnamed: 16                     3
# Unnamed: 17                     3
# Unnamed: 18                     3
# Unnamed: 19                    18
# Unnamed: 20                    18
# Unnamed: 21                    18
# SENTENCES IMPOSED BY COURTS    18
# Unnamed: 23                    19
# Unnamed: 24                    19
# Unnamed: 25                    18
# Unnamed: 26                    18
# ...

# %%
#dropping empty cells
data3=data1.dropna()
data3
# Out:
#     Unnamed: 0                            Unnamed: 1 REPORTED CASES  \
# 4            1                  Death  (by shooting)            190
# 5            2                 Death (by mob action)            636
# 6            3                     Death (Poisoning)             81
# 7            4  Death (Aggravated Domestic Violence)            362
# 8            5                Death(Fire Out Breaks)             42
# ..         ...                                   ...            ...
# 120         96                          Firearms Act            109
# 121         97                            Enguli Act              4
# 122         98                           UWA Statute            648
# 123         99                  Local Government Act              4
# 124        100                        All other Acts            821
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 PERFOMANCE Unnamed: 7 Unnamed: 8  \
# 4          117         29         44         74          3          1
# ...

# %%
null_values = df6.isnull().sum()
print(null_values)
# Out:
# No.                  0
# Name of M.P          0
# District             0
# Constituency         0
# Political Party      0
#                   ...
# Unnamed: 82        438
# Unnamed: 83        439
# Unnamed: 84        438
# Unnamed: 85        438
# Unnamed: 86        438
# Length: 87, dtype: int64

# %%
df6.columns
# Out:
# Index(['No.', 'Name of M.P', 'District', 'Constituency', 'Political Party',
#        'Profession', 'Marital status', 'Phone number', 'Date of Birth',
#        'P.L.E School', 'P.L.E Year', 'U.C.E School', 'U.C.E Year',
#        'U.A.C.E School', 'U.A.C.E Year', 'First Degree',
#        'University of First Degree', 'Year of first Degree', 'Second Degree',
#        'University of Second Degree', 'Year of second degree', 'Third Degree',
#        'University of Third Degree', 'Year of Third Degree',
#        'Other Qualifications', 'Past Job_1', 'Past Job_2', 'Past Job_3',
#        'Past Job_4', 'Past Job_5', 'Past Job_6', 'Past Job_7', 'Past Job_8',
#        'Past Job_9', 'Past Job_10', 'Hobbies', 'Special Interests',
#        'Other Information', 'Professional Body Membership', 'Committee_1',
#        'Role on Committee 1', 'Committee_2', 'Role on Committee 2',
#        'Committee_3', 'Role on Committee 3', 'Committee_4',
# ...

# %%
null_values = df6['Marital status'].isnull().sum()
print(null_values)
# Out:
# 3

# %%
null_values = df6['Name of M.P'].isnull().sum()
print(null_values)
# Out:
# 0

# %%
null_values = df6['Role on Committee 1'].isnull().sum()
print(null_values)
# Out:
# 105

# %%
#dropping empty cells
data4=df6['Role on Committee 1'].dropna()
data4
# Out:
# 1                Member
# 2                Member
# 3                Member
# 4      Vice Chairperson
# 5                Member
#              ...
# 433              Member
# 434              Member
# 436              Member
# 437              Member
# 438              Member
# Name: Role on Committee 1, Length: 334, dtype: object

# %%
# key objectives for analysing your dataset
# features of the colunms you are analyzing and why are you analyzing
# preprocessing and preparation head(10), tail(10)

import pandas as pd

df5.dropna(axis=1, how='all', inplace=True)

df5
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5244\1956084906.py in <module>
#       5 import pandas as pd
#       6
# ----> 7 df5.dropna(axis=1, how='all', inplace=True)
#       8
#       9 df5
#
# NameError: name 'df5' is not defined
