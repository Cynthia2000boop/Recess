# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# control display of seaborn data
pd. options.display.max_columns=50
sns.set(style="darkgrid", rc={"axes.facecolor":"CAF1DE"})

# %%
df4=pd.read_csv('bse_dataset4.csv')
df4
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
#confirm data shape
df4.shape
# Out:
# (169, 15)

# %%
df4.columns
# Out:
# Index(['Timestamp', 'gender', 'Age', 'emotion', 'YOB', 'CGPA',
#        'Do you have a Girl Friend or BOY Friend', 'Do you have Depression?',
#        'Do you have Anxiety?', 'Do you have Panic attack?',
#        'Did you have seek any specialist for a treatment? ', 'Duration',
#        'Pulse', 'Maxpulse', 'Calories'],
#       dtype='object')

# %%
#dropping empty cells
df3=df4.dropna()
df3
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
#df3=df4.dropna(inplace=True)
#df3

# %%
# filling empty cells with a value
#df4.fillna(value=100,inplace=True)
#df4

# %%
df4['Calories'].fillna(100,inplace=True)
df4
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
# replace using mean,median,mode
#calculate Mean
m=df4['Age'].mean()
df4['Age'].fillna(m,inplace=True)
df4
# Out:
#                Timestamp         gender   Age  emotion   YOB     CGPA  \
# 0    05/07/2023 09:38:39           Male  21.0  Content  2002     4.22
# 1    05/07/2023 09:38:57  Marabou stock  45.0    Weird  2100      8.9
# 2    05/07/2023 09:39:09        Female   20.0    Happy  2002     3.98
# 3    05/07/2023 09:39:12           Male  21.0    Happy  2003     4.37
# 4    05/07/2023 09:39:14         Female  21.0    Happy  2002     3.63
# ..                   ...            ...   ...      ...   ...      ...
# 164  05/07/2023 09:44:09           Male  22.0   Angry   1999      3.5
# 165  05/07/2023 09:44:14           male  23.0      sad  1999        4
# 166  05/07/2023 09:44:15           male  20.0     calm  2002      3.7
# 167  05/07/2023 09:44:35         Female  21.0      sad  2001      3.8
# 168  05/07/2023 09:45:13         Female  20.0    Happy  2022  4......
#
#     Do you have a Girl Friend or BOY Friend Do you have Depression?  \
# ...

# %%
# displaying all rows and columns
pd.set_option('display.max_rows',None)
pd.set_option('display.max_columns',None)
df4
# Out:
#                Timestamp         gender        Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.000000               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.000000                 Weird
# 2    05/07/2023 09:39:09        Female   20.000000                 Happy
# 3    05/07/2023 09:39:12           Male  21.000000                 Happy
# 4    05/07/2023 09:39:14         Female  21.000000                 Happy
# 5                    NaN         Female  23.000000                Happy
# 6    05/07/2023 09:39:21         female  21.000000            irritated
# 7    05/07/2023 09:39:23        Female   22.000000  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.000000                   Sad
# 9    05/07/2023 09:39:27         Female  20.000000                 happy
# 10            2023/12/26           Male  24.000000                 Happy
# 11   05/07/2023 09:39:27         Female  20.000000                 happy
# ...

# %%
# empty cells, wrong data,wrong formats,duplicates (core of data preparation and processing)
# calculating median
md=df4['Calories'].median()
df4['Calories'].fillna(md,inplace=True)
df4
# Out:
#                Timestamp         gender        Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.000000               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.000000                 Weird
# 2    05/07/2023 09:39:09        Female   20.000000                 Happy
# 3    05/07/2023 09:39:12           Male  21.000000                 Happy
# 4    05/07/2023 09:39:14         Female  21.000000                 Happy
# 5                    NaN         Female  23.000000                Happy
# 6    05/07/2023 09:39:21         female  21.000000            irritated
# 7    05/07/2023 09:39:23        Female   22.000000  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.000000                   Sad
# 9    05/07/2023 09:39:27         Female  20.000000                 happy
# 10            2023/12/26           Male  24.000000                 Happy
# 11   05/07/2023 09:39:27         Female  20.000000                 happy
# ...

# %%
md=df4['Calories'].median()
print(md)
# Out:
# 310.2

# %%
#exercise 1
#calculate mode on Age
mo=df4['Age'].mode()
print(mo)
# Out:
# 0    21.0
# Name: Age, dtype: float64

# %%
#wrong formats. rows that are hard to analyse

df4['Timestamp'].fillna('05/07/2023 09:39:09',inplace=True)
df4
# Out:
#                Timestamp         gender        Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.000000               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.000000                 Weird
# 2    05/07/2023 09:39:09        Female   20.000000                 Happy
# 3    05/07/2023 09:39:12           Male  21.000000                 Happy
# 4    05/07/2023 09:39:14         Female  21.000000                 Happy
# 5    05/07/2023 09:39:09         Female  23.000000                Happy
# 6    05/07/2023 09:39:21         female  21.000000            irritated
# 7    05/07/2023 09:39:23        Female   22.000000  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.000000                   Sad
# 9    05/07/2023 09:39:27         Female  20.000000                 happy
# 10            2023/12/26           Male  24.000000                 Happy
# 11   05/07/2023 09:39:27         Female  20.000000                 happy
# ...

# %%
# wrong data 
#df4=pd.read_csv('bse_dataset4.csv')
#for x df4.index:
    #if df4.loc[x,"gender"]=="Marabou stock"
       # df4.drop(x,inplace=True)
#df4
#import pandas as pd

#df4 = pd.read_csv('bse_dataset4.csv')

for x in df4.index:
    if df4.loc[x, "gender"] == "Marabou stock":
        df4.drop(x, inplace=True)

# %%
print(df4.duplicated())
# Out:
# 0      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# Length: 168, dtype: bool

# %%
df4.drop_duplicates()
# Out:
#                Timestamp         gender        Age               emotion  \
# 0    05/07/2023 09:38:39           Male  21.000000               Content
# 1    05/07/2023 09:38:57  Marabou stock  45.000000                 Weird
# 2    05/07/2023 09:39:09        Female   20.000000                 Happy
# 3    05/07/2023 09:39:12           Male  21.000000                 Happy
# 4    05/07/2023 09:39:14         Female  21.000000                 Happy
# 5    05/07/2023 09:39:09         Female  23.000000                Happy
# 6    05/07/2023 09:39:21         female  21.000000            irritated
# 7    05/07/2023 09:39:23        Female   22.000000  In a state of wonder
# 8    05/07/2023 09:39:26           Male  22.000000                   Sad
# 9    05/07/2023 09:39:27         Female  20.000000                 happy
# 10            2023/12/26           Male  24.000000                 Happy
# 12   05/07/2023 09:39:38           Male  25.000000                 Happy
# ...

# %%
# data visualization, plotting,matplot loaded.
# They are heatmap, piechart, barchart, lineplot(dotted and dashed),histogram

# %%
import matplotlib.pyplot as plt

df4["Age"].plot(kind="hist")

plt.show()

# %%
import matplotlib.pyplot as plt

df4["Age"].plot(kind="pie")

plt.show()

# %%
import matplotlib.pyplot as plt

df4["Age"].plot(kind="bar")

plt.show()
